# %%
import pandas as pd               
df = pd.DataFrame()
df
#OUTPUT in IDLE
#Empty DataFrame
#Columns: []
#Index: []
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df = pd.DataFrame([1,2,3,4,5])
df                                  # 0 in output above our given array is the default column
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
df=pd.DataFrame({1:[1,2,3,4,5]})
df
# Out:
#    1
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
df=pd.DataFrame({'one':[1,2,3,4,5]})
df
# Out:
#    one
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5

# %%
df=pd.DataFrame({'one':[1,2,3,4,5],'two':[1,2,3,4,5]})
df
# Out:
#    one  two
# 0    1    1
# 1    2    2
# 2    3    3
# 3    4    4
# 4    5    5

# %%
df=pd.DataFrame({'one':[1,2,3,4,5],'two':[1,2,3,4,5]},index=['a','b','c','d','f'])
df
# Out:
#    one  two
# a    1    1
# b    2    2
# c    3    3
# d    4    4
# f    5    5

# %%
df[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df1=pd.DataFrame({'one':[1,2,3,4,5],'two':[1,2,3,4,5]})
df1
# Out:
#    one  two
# 0    1    1
# 1    2    2
# 2    3    3
# 3    4    4
# 4    5    5

# %%
df1[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df2=pd.DataFrame({1:[1,2,3,4,5]})
df2
# Out:
#    1
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
df2[1]
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: 1, dtype: int64

# %%
df
# Out:
#    one  two
# a    1    1
# b    2    2
# c    3    3
# d    4    4
# f    5    5

# %%
df['one']    # loc and iloc
# Out:
# a    1
# b    2
# c    3
# d    4
# f    5
# Name: one, dtype: int64

# %%
df.loc['one']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'one'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.loc[:,'one']
# Out:
# a    1
# b    2
# c    3
# d    4
# f    5
# Name: one, dtype: int64

# %%
df1
# Out:
#    one  two
# 0    1    1
# 1    2    2
# 2    3    3
# 3    4    4
# 4    5    5

# %%
df1.loc[:,'one']
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: one, dtype: int64

# %%
df1.loc[:2,'one']
# Out:
# 0    1
# 1    2
# 2    3
# Name: one, dtype: int64

# %%
df1.loc[:-1,'one']
# Out:
# Series([], Name: one, dtype: int64)

# %%
df1.loc[2:4,'one']
# Out:
# 2    3
# 3    4
# 4    5
# Name: one, dtype: int64

# %%
df1.loc[2:4,'one':'two']
# Out:
#    one  two
# 2    3    3
# 3    4    4
# 4    5    5

# %%
df1.loc[2:4,['one':'two']]
# Out:
#   File "<ipython-input-22-12f138315a22>", line 1
#     df1.loc[2:4,['one':'two']]
#                       ^
# SyntaxError: invalid syntax

# %%
df1.loc[2:4,['one','two']]
# Out:
#    one  two
# 2    3    3
# 3    4    4
# 4    5    5

# %%
df
# Out:
#    one  two
# a    1    1
# b    2    2
# c    3    3
# d    4    4
# f    5    5

# %%
df.loc[2:4,['one','two']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-6b011370c1fe> in <module>()
# ----> 1 df.loc[2:4,['one','two']]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1107             return self._multi_take(tup)
#    1108
# -> 1109         return self._getitem_tuple_same_dim(tup)
#    1110
#    1111     def _get_label(self, label, axis: int):
#
# ...

# %%
df.iloc[:3,:]
# Out:
#    one  two
# a    1    1
# b    2    2
# c    3    3

# %%
df.iloc[1:3,:]
# Out:
#    one  two
# b    2    2
# c    3    3

# %%
df.iloc[1:3,:1]
# Out:
#    one
# b    2
# c    3

# %%
df.iloc[1:3,1:2]
# Out:
#    two
# b    2
# c    3

# %%
df1
# Out:
#    one  two
# 0    1    1
# 1    2    2
# 2    3    3
# 3    4    4
# 4    5    5

# %%
df1.iloc[1:3,1:2]
# Out:
#    two
# 1    2
# 2    3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, a to f
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   one     5 non-null      int64
#  1   two     5 non-null      int64
# dtypes: int64(2)
# memory usage: 292.0+ bytes

# %%
df.isna()
# Out:
#      one    two
# a  False  False
# b  False  False
# c  False  False
# d  False  False
# f  False  False

# %%
df.isnull()
# Out:
#      one    two
# a  False  False
# b  False  False
# c  False  False
# d  False  False
# f  False  False

# %%
df.isna().sum()
# Out:
# one    0
# two    0
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df['one']
# Out:
# a    1
# b    2
# c    3
# d    4
# f    5
# Name: one, dtype: int64

# %%
df['one'].sum()
# Out:
# 15

# %%
df['one'].max()
# Out:
# 5

# %%
df['one'].median()
# Out:
# 3.0

# %%
import numpy as np
df=pd.DataFrame({'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']},
index = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'])
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      10 non-null     object
#  1   score     8 non-null      float64
#  2   attempts  10 non-null     int64
#  3   qualify   10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes

# %%
df.isna()
# Out:
#     name  score  attempts  qualify
# a  False  False     False    False
# b  False  False     False    False
# c  False  False     False    False
# d  False   True     False    False
# e  False  False     False    False
# f  False  False     False    False
# g  False  False     False    False
# h  False   True     False    False
# i  False  False     False    False
# j  False  False     False    False

# %%
df.isna().sum()
# Out:
# name        0
# score       2
# attempts    0
# qualify     0
# dtype: int64

# %%
df.loc[:,['name','score']]
# Out:
#         name  score
# a  Anastasia   12.5
# b       Dima    9.0
# c  Katherine   16.5
# d      James    NaN
# e      Emily    9.0
# f    Michael   20.0
# g    Matthew   14.5
# h      Laura    NaN
# i      Kevin    8.0
# j      Jonas   19.0

# %%
df.columns
# Out:
# Index(['name', 'score', 'attempts', 'qualify'], dtype='object')

# %%
df.iloc[:,:2]
# Out:
#         name  score
# a  Anastasia   12.5
# b       Dima    9.0
# c  Katherine   16.5
# d      James    NaN
# e      Emily    9.0
# f    Michael   20.0
# g    Matthew   14.5
# h      Laura    NaN
# i      Kevin    8.0
# j      Jonas   19.0

# %%
df.iloc[[1,3,5,6],:2]
# Out:
#       name  score
# b     Dima    9.0
# d    James    NaN
# f  Michael   20.0
# g  Matthew   14.5

# %%
df.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'], dtype='object')

# %%
df.loc[['b','d','f','g']:'name','score']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-55a8cf74fefa> in <module>()
# ----> 1 df.loc[['b','d','f','g']:'name','score']
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1098     def _getitem_tuple(self, tup: tuple):
#    1099         with suppress(IndexingError):
# -> 1100             return self._getitem_lowerdim(tup)
#    1101
#    1102         # no multi-index, so validate all of the indexers
#
# ...

# %%
df.loc[['b','d','f','g'],['name','score']]
# Out:
#       name  score
# b     Dima    9.0
# d    James    NaN
# f  Michael   20.0
# g  Matthew   14.5

# %%
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
df['attempts']>2
# Out:
# a    False
# b     True
# c    False
# d     True
# e    False
# f     True
# g    False
# h    False
# i    False
# j    False
# Name: attempts, dtype: bool

# %%
df[df['attempts']>2]
# Out:
#       name  score  attempts qualify
# b     Dima    9.0         3      no
# d    James    NaN         3      no
# f  Michael   20.0         3     yes

# %%
len(df)
# Out:
# 10

# %%
len(df.columns)
# Out:
# 4

# %%
len(df.index)
# Out:
# 10

# %%
df.shape
# Out:
# (10, 4)

# %%
df['score']==np.nan
# Out:
# a    False
# b    False
# c    False
# d    False
# e    False
# f    False
# g    False
# h    False
# i    False
# j    False
# Name: score, dtype: bool

# %%
df['score']
# Out:
# a    12.5
# b     9.0
# c    16.5
# d     NaN
# e     9.0
# f    20.0
# g    14.5
# h     NaN
# i     8.0
# j    19.0
# Name: score, dtype: float64

# %%
df['score']==np.na
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-fc2cf2a34860> in <module>()
# ----> 1 df['score']==np.na
#
# /usr/local/lib/python3.7/dist-packages/numpy/__init__.py in __getattr__(attr)
#     312
#     313             raise AttributeError("module {!r} has no attribute "
# --> 314                                  "{!r}".format(__name__, attr))
#     315
#     316         def __dir__():
#
# AttributeError: module 'numpy' has no attribute 'na'

# %%
df['score']==np.NaN
# Out:
# a    False
# b    False
# c    False
# d    False
# e    False
# f    False
# g    False
# h    False
# i    False
# j    False
# Name: score, dtype: bool

# %%
df['score']==NULL
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-a9562f157baf> in <module>()
# ----> 1 df['score']==NULL
#
# NameError: name 'NULL' is not defined

# %%
df['score'].isna()
# Out:
# a    False
# b    False
# c    False
# d     True
# e    False
# f    False
# g    False
# h     True
# i    False
# j    False
# Name: score, dtype: bool

# %%
df[df['score'].isna()]
# Out:
#     name  score  attempts qualify
# d  James    NaN         3      no
# h  Laura    NaN         1      no

# %%
df[df['score'].isna()]['name']
# Out:
# d    James
# h    Laura
# Name: name, dtype: object

# %%
df[df['score'].isna()][['attempts','name','score']]
# Out:
#    attempts   name  score
# d         3  James    NaN
# h         1  Laura    NaN

# %%
df[df['score']==10]
# Empty DataFrame
# Columns: [name, score, attempts, qualify]
# Index: []
# Out:
# Empty DataFrame
# Columns: [name, score, attempts, qualify]
# Index: []

# %%
df[df['score']>15]
# Out:
#         name  score  attempts qualify
# c  Katherine   16.5         2     yes
# f    Michael   20.0         3     yes
# j      Jonas   19.0         1     yes

# %%
df[(df['score']>15) & (df['score']<=20)]
# Out:
#         name  score  attempts qualify
# c  Katherine   16.5         2     yes
# f    Michael   20.0         3     yes
# j      Jonas   19.0         1     yes

# %%
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
df.loc['d','score']
# Out:
# nan

# %%
df.loc['d','score']=111.5

# %%
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James  111.5         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
df.append({'attempts':[1],'name':['Suresh'],'qualify':['yes'],'score':[15.5]},index=['k'])  
# Append can only be used to merge two data frames with same number and name of columns.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-972b700db9a8> in <module>()
# ----> 1 df.append({'attempts':[1],'name':['Suresh'],'qualify':['yes'],'score':[15.5]},index=['k'])  # Append can only be used to merge two data frames with same number and name of columns
#
# TypeError: append() got an unexpected keyword argument 'index'
